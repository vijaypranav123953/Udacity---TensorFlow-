# %% [markdown]
#   # The First Program - Hello World
#
#   The code for doing this in C Language:-
#
#   ```C
#   #include<stdio.h>
#
#   int main(){
#     printf("Hello World");
#     return 0;
#   }
#   ```

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Fundamentals

# %% [markdown]
# ## Variables and Literals

# %%
integer = 18
rational= 1.8
string = "Virat Kohli"
boolean = True

print(integer, rational, string, boolean)

# %% [markdown]
# ## Type Conversion

# %%
integer_number = 18
string_number = "18"

print(integer_number + int(string_number))

# %% [markdown]
# ## Input and Output

# %% [markdown]
# ### Output

# %%
# Basic
print("This is how you output in Python")

# Varinbles  Printing
print(integer)

# Formatted String
print(f"Virat Jersey Number = {integer}")

# %% [markdown]
# ### Input

# %%
input_string = input("Enter a string : ")
print(input_string)

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Arithmetic

# %%
a = 7
b = 2

# addition
print ('Sum: ', a + b)

# subtraction
print ('Subtraction: ', a - b)

# multiplication
print ('Multiplication: ', a * b)

# division
print ('Division: ', a / b)

# floor division
print ('Floor Division: ', a // b)

# modulo
print ('Modulo: ', a % b)

# a to the power b
print ('Power: ', a ** b)

# %% [markdown]
# ### Assignment

# %%
a = 10
b = 5
a += b

print(a)

# %% [markdown]
# ### Comparision

# %%
a = 5

b = 2

# equal to operator
print('a == b =', a == b)

# not equal to operator
print('a != b =', a != b)

# greater than operator
print('a > b =', a > b)

# less than operator
print('a < b =', a < b)

# greater than or equal to operator
print('a >= b =', a >= b)

# less than or equal to operator
print('a <= b =', a <= b)

# %% [markdown]
# # Control Flow

# %% [markdown]
# ## if - else

# %% [markdown]
# ### If and Else

# %%
number = int(input('Enter a number: '))

if number > 0:
    print('Positive number')
else:
    print('Not a positive number')

print('This statement always executes')

# %% [markdown]
# ### If, Elif and Else

# %%
number = -5

if number > 0:
    print('Positive number')

elif number < 0:
    print('Negative number')

else:
    print('Zero')

print('This statement is always executed')

# %% [markdown]
# ### Nested Ifs

# %%
number = 5

# outer if statement
if number >= 0:
    # inner if statement
    if number == 0:
      print('Number is 0')

    # inner else statement
    else:
        print('Number is positive')

# outer else statement
else:
    print('Number is negative')

# %% [markdown]
# ## for

# %% [markdown]
# ### Using List

# %%
languages = ['Swift', 'Python', 'Go']

for lang in languages:
    print(lang)

# %% [markdown]
# ### Using Range

# %%
for i in range(4):
    print(i)

# %% [markdown]
# ## while

# %%
number = 1

while number <= 3:
    print(number)
    number = number + 1

print(number)

# %% [markdown]
# ## break and continue

# %%
for i in range(10):
  if i == 3:
      break  # Exit the loop immediately
  elif i == 5:
      continue  # Skip the rest of the loop body for this iteration
  else:
      print(i)

# %% [markdown]
# # Data Types

# %% [markdown]
# ## Math in Python

# %%
# type function
num1 = 5
print(num1, 'is of type', type(num1))
num2 = 5.42
print(num2, 'is of type', type(num2))
num3 = 8+2j
print(num3, 'is of type', type(num3))

# %%
import math

print(math.pi)

print(math.cos(math.pi))

print(math.exp(10))

print(math.log10(1000))

print(math.sinh(1))

print(math.factorial(6))

# %% [markdown]
# ## List

# %%
fruits = ['apple', 'banana', 'orange']
print('Original List:', fruits)

# using append method
fruits.append('cherry')

print('Updated List:', fruits)

# Updation
fruits[1] = 'cherry'
print('Updated List:', fruits)

# Deletion
fruits.remove('cherry')
print('Updated List:', fruits)

# Length of list
print(len(fruits))

# %% [markdown]
# ## Tuples

# %%
# Creation
numbers = (1, 2, -5)
print(numbers)

# Access
print(numbers[2])

# Length of the Tuple
print(len(numbers))

# %% [markdown]
# ## String

# %% [markdown]
# ### Basic

# %%
string = "This is a sample string"

# Accessing
print(string[1])
print(string[1:4])
print(string[-3])

# %% [markdown]
# ### Operations

# %%
str1 = "This is the string 1"
str2 = "This is the string 2"

# compare str1 and str2
print(str1 == str2)

# Concatenation
result = str1 + str2
print(result)

# Iterating
for letter in str1:
    print(letter)

# Length of the string
print(len(str1))

# String ownership
print('a' in 'program')

# %% [markdown]
# ## Set

# %%
mixed_set = {'Hello', 101, -2, 'Bye'}
print('Set of mixed data types:', mixed_set)

mixed_set.add(18.3)
print(mixed_set)

print(len(mixed_set))

mixed_set.remove('Bye')
print(mixed_set)

# %%
# first set
A = {1, 3, 5}

# second set
B = {1, 2, 3}

print('Union using |:', A | B)
print('Intersection using &:', A & B)
print('Difference using -:', A - B)
print('using ^:', A ^ B)

# %% [markdown]
# ## Dictionary

# %%
state_capitals = {
  "TN": "Chennai",
  "AP": "Amaravati",
  "TS": "Hyderabad"
}

# Access
print(state_capitals['TS'])

# Add
state_capitals['KL'] = 'Thiruvananthapuram'
print(state_capitals)

# Update
state_capitals['AP'] = 'Vizag'
print(state_capitals)

# Delete
del state_capitals['KL']
print(state_capitals)

# Iterate
for state in state_capitals:
    capital = state_capitals[capital]
    print(capital)

# %% [markdown]
# # Functions

# %% [markdown]
# ## Basic Function

# %%
def greet():
    print('Hello World!')


greet()

# %% [markdown]
# ## Function with arguments

# %%
# function with two arguments
def add_numbers(num1, num2):
    sum = num1 + num2
    print("Sum: ", sum)

# function call with two values
add_numbers(5, 4)

# %%
# function definition
def find_square(num):
    result = num * num
    return result

# function call
square = find_square(3)

print('Square:', square)

# %% [markdown]
# ## Recursion

# %%
def factorial(x):

    if x == 1:
        return 1
    else:
        return (x * factorial(x-1))


num = 3
print("The factorial of", num, "is", factorial(num))

# %% [markdown]
# ## Modules

# %%
# import standard math module
import math

# use math.pi to get value of pi
print("The value of pi is", math.pi)

# %% [markdown]
# ## Main Function

# %%
def main():
    print("Hello World")

if __name__=="__main__":
    main()
